# %%
import pandas as pd

# %% [markdown]
# # Read and Clean part1_1982-2017.csv Well Data

# %%
welldata01_df = pd.read_csv("data/part1_1982-2017.csv")
welldata01_df.head()
# Out:
#               api     API/UWI              Operator Alias  \
# 0  42301331730000  4230133173   ANADARKO E&P ONSHORE, LLC
# 1  42301333080000  4230133308      MEWBOURNE HOLDINGS INC
# 2  42301332080000  4230133208  EOG RESOURCES INCORPORATED
# 3  42301330570000  4230133057    DEVON ENERGY CORPORATION
# 4  42301330560000  4230133056      MEWBOURNE HOLDINGS INC
#
#         Well/Lease Name Well Number    Reservoir Production Type  \
# 0   SAVAGE 54-2-22 UNIT          1H     WOLFCAMP             OIL
# 1     ZUMA 3 57-T1-3X10      W102AP     WOLFCAMP             OIL
# 2  LINK VJ RANCH 23-11B          2H     WOLFCAMP             OIL
# 3          BOYD 11 101H        101H     WOLFCAMP             OIL
# 4                TXL 19      H301DM  BONE SPRING             OIL
#
#   Producing Status Drill Type First Prod Date            ...              \
# 0           ACTIVE          H        7/1/2017            ...
# 1           ACTIVE          H        7/1/2017            ...
# 2           ACTIVE          H        7/1/2017            ...
# 3           ACTIVE          H        5/1/2017            ...
# 4           ACTIVE          H        7/1/2017            ...
#
#    Months Produced  Spud Date  Measured Depth (TD)  True Vertical Depth  \
# 0                1  3/27/2017                12100                  NaN
# 1                1   5/8/2017                20470                  NaN
# 2                1   4/8/2017                14000                  NaN
# 3                2  1/22/2017                17570                  NaN
# 4                1  4/24/2017                14375                  NaN
#
#    Perforated Interval Length    Field  Section Block  \
# 0                         NaN  PHANTOM      NaN   NaN
# 1                         NaN  PHANTOM      NaN   NaN
# 2                         NaN  PHANTOM      NaN   NaN
# 3                         NaN  PHANTOM      NaN   NaN
# 4                         NaN  SANDBAR      NaN   NaN
#
#    Surface Latitude (WGS84)  Surface Longitude (WGS84)
# 0                 31.826158                -103.643763
# 1                 31.999605                -103.941079
# 2                 31.838967                -103.735467
# 3                 31.943227                -103.354456
# 4                 31.955776                -103.905377
#
# [5 rows x 38 columns]

# %%
del welldata01_df['api']
welldata01_df.head()
# Out:
#       API/UWI              Operator Alias       Well/Lease Name Well Number  \
# 0  4230133173   ANADARKO E&P ONSHORE, LLC   SAVAGE 54-2-22 UNIT          1H
# 1  4230133308      MEWBOURNE HOLDINGS INC     ZUMA 3 57-T1-3X10      W102AP
# 2  4230133208  EOG RESOURCES INCORPORATED  LINK VJ RANCH 23-11B          2H
# 3  4230133057    DEVON ENERGY CORPORATION          BOYD 11 101H        101H
# 4  4230133056      MEWBOURNE HOLDINGS INC                TXL 19      H301DM
#
#      Reservoir Production Type Producing Status Drill Type First Prod Date  \
# 0     WOLFCAMP             OIL           ACTIVE          H        7/1/2017
# 1     WOLFCAMP             OIL           ACTIVE          H        7/1/2017
# 2     WOLFCAMP             OIL           ACTIVE          H        7/1/2017
# 3     WOLFCAMP             OIL           ACTIVE          H        5/1/2017
# 4  BONE SPRING             OIL           ACTIVE          H        7/1/2017
#
#    Cum Gas            ...              Months Produced  Spud Date  \
# 0  22456.0            ...                            1  3/27/2017
# 1     72.0            ...                            1   5/8/2017
# 2  74305.0            ...                            1   4/8/2017
# 3  40193.0            ...                            2  1/22/2017
# 4  43538.0            ...                            1  4/24/2017
#
#    Measured Depth (TD)  True Vertical Depth  Perforated Interval Length  \
# 0                12100                  NaN                         NaN
# 1                20470                  NaN                         NaN
# 2                14000                  NaN                         NaN
# 3                17570                  NaN                         NaN
# 4                14375                  NaN                         NaN
#
#      Field Section  Block  Surface Latitude (WGS84)  Surface Longitude (WGS84)
# 0  PHANTOM     NaN    NaN                 31.826158                -103.643763
# 1  PHANTOM     NaN    NaN                 31.999605                -103.941079
# 2  PHANTOM     NaN    NaN                 31.838967                -103.735467
# 3  PHANTOM     NaN    NaN                 31.943227                -103.354456
# 4  SANDBAR     NaN    NaN                 31.955776                -103.905377
#
# [5 rows x 37 columns]

# %%
#list all the header column 
list(welldata01_df)
# Out:
# ['API/UWI',
#  'Operator Alias',
#  'Well/Lease Name',
#  'Well Number',
#  'Reservoir',
#  'Production Type',
#  'Producing Status',
#  'Drill Type',
#  'First Prod Date',
#  'Cum Gas',
#  'Cum Oil',
#  'Cum BOE',
#  'Daily Gas',
#  'Daily Oil',
#  'First Month Oil',
#  'First Month Gas',
#  'Last Test Date',
#  'Last Flow Pressure',
#  'Peak Gas',
#  'Peak Oil',
#  'Peak BOE',
#  'Upper Perforation',
#  'Lower Perforation',
#  'Gas Gravity',
#  'Oil Gravity',
#  'Completion Date',
#  'Well Count',
#  'Months Produced',
#  'Spud Date',
#  'Measured Depth (TD)',
#  'True Vertical Depth',
#  'Perforated Interval Length',
#  'Field',
#  'Section',
#  'Block',
#  'Surface Latitude (WGS84)',
#  'Surface Longitude (WGS84)']

# %%
# renamer the columns header
welldata01_df.rename(columns={
 'API/UWI':'API',
 'Operator Alias': 'Operator',
 'Well/Lease Name':'Lease_Name',
 'Well Number':'Well_Number',
 'Production Type': 'Production_type',
 'Producing Status':'Production_Status',
 'Drill Type':'Drilling_Type',
 'First Prod Date':'First_Production_Day',
 'Cum Gas':'Cum_Gas',
 'Cum Oil':'Cum_Oil',
 'Cum BOE':'Cum_BOE',
 'Daily Gas':'Daily_Gas',
 'Daily Oil':'Daily_Oil',
 'First Month Oil':'First_Month_Oil',
 'First Month Gas':'First_Month_Gas',
 'Last Test Date':'Last_Test_Date',
 'Last Flow Pressure':'Last_Flow_Pressure',
 'Peak Gas':'Peak_Gas',
 'Peak Oil':'Peak_Oil',
 'Peak BOE':'Peak_BOE',
 'Upper Perforation':'Upper_Perforation',
 'Lower Perforation':'Lower_Perforation',
 'Gas Gravity':'Gas_Gravity',
 'Oil Gravity':'Oil_Gravity',
 'Completion Date':'Completion_Date',
 'Well Count':'Well_Count',
 'Months Produced':'Months_Produced',
 'Spud Date':'Spud_Date',
 'Measured Depth (TD)':'TD',
 'True Vertical Depth':'TVD',
 'Perforated Interval Length':'Perforated_Interval_Length',
 'Surface Latitude (WGS84)':'Lat',
 'Surface Longitude (WGS84)':'Long'}, inplace=True)

# %%
welldata01_df.head()
# Out:
#           API                    Operator            Lease_Name Well_Number  \
# 0  4230133173   ANADARKO E&P ONSHORE, LLC   SAVAGE 54-2-22 UNIT          1H
# 1  4230133308      MEWBOURNE HOLDINGS INC     ZUMA 3 57-T1-3X10      W102AP
# 2  4230133208  EOG RESOURCES INCORPORATED  LINK VJ RANCH 23-11B          2H
# 3  4230133057    DEVON ENERGY CORPORATION          BOYD 11 101H        101H
# 4  4230133056      MEWBOURNE HOLDINGS INC                TXL 19      H301DM
#
#      Reservoir Production_type Production_Status Drilling_Type  \
# 0     WOLFCAMP             OIL            ACTIVE             H
# 1     WOLFCAMP             OIL            ACTIVE             H
# 2     WOLFCAMP             OIL            ACTIVE             H
# 3     WOLFCAMP             OIL            ACTIVE             H
# 4  BONE SPRING             OIL            ACTIVE             H
#
#   First_Production_Day  Cum_Gas     ...      Months_Produced  Spud_Date  \
# 0             7/1/2017  22456.0     ...                    1  3/27/2017
# 1             7/1/2017     72.0     ...                    1   5/8/2017
# 2             7/1/2017  74305.0     ...                    1   4/8/2017
# 3             5/1/2017  40193.0     ...                    2  1/22/2017
# 4             7/1/2017  43538.0     ...                    1  4/24/2017
#
#       TD  TVD  Perforated_Interval_Length    Field Section  Block        Lat  \
# 0  12100  NaN                         NaN  PHANTOM     NaN    NaN  31.826158
# 1  20470  NaN                         NaN  PHANTOM     NaN    NaN  31.999605
# 2  14000  NaN                         NaN  PHANTOM     NaN    NaN  31.838967
# 3  17570  NaN                         NaN  PHANTOM     NaN    NaN  31.943227
# 4  14375  NaN                         NaN  SANDBAR     NaN    NaN  31.955776
#
#          Long
# 0 -103.643763
# 1 -103.941079
# 2 -103.735467
# 3 -103.354456
# 4 -103.905377
#
# [5 rows x 37 columns]

# %%
welldata01_df['API'] = welldata01_df['API'].replace('0000','')

# %%
welldata01_df.head()
# Out:
#           API                    Operator            Lease_Name Well_Number  \
# 0  4230133173   ANADARKO E&P ONSHORE, LLC   SAVAGE 54-2-22 UNIT          1H
# 1  4230133308      MEWBOURNE HOLDINGS INC     ZUMA 3 57-T1-3X10      W102AP
# 2  4230133208  EOG RESOURCES INCORPORATED  LINK VJ RANCH 23-11B          2H
# 3  4230133057    DEVON ENERGY CORPORATION          BOYD 11 101H        101H
# 4  4230133056      MEWBOURNE HOLDINGS INC                TXL 19      H301DM
#
#      Reservoir Production_type Production_Status Drilling_Type  \
# 0     WOLFCAMP             OIL            ACTIVE             H
# 1     WOLFCAMP             OIL            ACTIVE             H
# 2     WOLFCAMP             OIL            ACTIVE             H
# 3     WOLFCAMP             OIL            ACTIVE             H
# 4  BONE SPRING             OIL            ACTIVE             H
#
#   First_Production_Day  Cum_Gas     ...      Months_Produced  Spud_Date  \
# 0             7/1/2017  22456.0     ...                    1  3/27/2017
# 1             7/1/2017     72.0     ...                    1   5/8/2017
# 2             7/1/2017  74305.0     ...                    1   4/8/2017
# 3             5/1/2017  40193.0     ...                    2  1/22/2017
# 4             7/1/2017  43538.0     ...                    1  4/24/2017
#
#       TD  TVD  Perforated_Interval_Length    Field Section  Block        Lat  \
# 0  12100  NaN                         NaN  PHANTOM     NaN    NaN  31.826158
# 1  20470  NaN                         NaN  PHANTOM     NaN    NaN  31.999605
# 2  14000  NaN                         NaN  PHANTOM     NaN    NaN  31.838967
# 3  17570  NaN                         NaN  PHANTOM     NaN    NaN  31.943227
# 4  14375  NaN                         NaN  SANDBAR     NaN    NaN  31.955776
#
#          Long
# 0 -103.643763
# 1 -103.941079
# 2 -103.735467
# 3 -103.354456
# 4 -103.905377
#
# [5 rows x 37 columns]

# %%
welldata01_df.to_csv('data/Part1_WellData_Cleaned.csv')

# %% [markdown]
# # Read and Clean part2_2017-2019.csv Well Data

# %%
# merging dataset data_2_1 and data_2_2
data_2_1_df = pd.read_csv('data/data_2_1.csv')
data_2_2_df = pd.read_csv('data/data_2_2.csv')

data_3_df = pd.merge(data_2_1_df, data_2_2_df, on='API')
# data_3_df.head()

# %%
data_2_4_df = pd.read_csv('data/data_2_3.csv')

# %%
# merge data_3 and data_2_3
welldata02_df = pd.merge(data_3_df, data_2_3_df, on='API')
welldata02_df.head()
# Out:
#                  API                           Name Well Type - Aliased  \
# 0  42-301-32426-0000    THRESHER 55-1-12 UNIT A 15H              PERMIT
# 1  42-301-32426-0000    THRESHER 55-1-12 UNIT A 15H              PERMIT
# 2  42-301-32427-0000    THRESHER 55-1-12 UNIT A 16H                 OIL
# 3  42-301-32427-0000    THRESHER 55-1-12 UNIT A 16H                 OIL
# 4  42-301-32973-0000  WAR ADMIRAL 28-4 UNIT D 1H 1H                 OIL
#
#   Status - Aliased Wellbore Profile - Aliased First Production Date   CUM Oil  \
# 0     OPEN SHUT IN                 HORIZONTAL              4/1/2018    9091.0
# 1     OPEN SHUT IN                 HORIZONTAL              4/1/2018    9091.0
# 2           Active                 HORIZONTAL              4/1/2018    9091.0
# 3           Active                 HORIZONTAL              4/1/2018    9091.0
# 4           Active                 HORIZONTAL              9/1/2018  228666.0
#
#     CUM Gas  CUM Water   Latitude      ...       Lateral Length  Spud Date  \
# 0   13875.0        0.0  31.981396      ...          9087.059570  1/31/2018
# 1   13875.0        0.0  31.981396      ...          9087.059570  1/31/2018
# 2   13875.0        0.0  31.981394      ...          9079.295898  2/11/2018
# 3   13875.0        0.0  31.981394      ...          9079.295898  2/11/2018
# 4  318442.0        0.0  31.844194      ...         11127.969730  7/12/2018
#
#   Completion Date Well Number Upper Perf  Lower Perf  Formation  \
# 0             NaN         NaN          0           0        NaN
# 1       3/18/2018         15H          0           0        NaN
# 2             NaN         NaN          0           0        NaN
# 3        3/5/2018         16H          0           0        NaN
# 4       9/21/2018          1H      12689       22769   WOLFCAMP
#
#                   operator         STATUS well profile
# 0                       NaN  OPEN SHUT IN    HORIZONTAL
# 1  ANADARKO E&P ONSHORE LLC  OPEN SHUT IN    HORIZONTAL
# 2                       NaN        Active    HORIZONTAL
# 3  ANADARKO E&P ONSHORE LLC        Active    HORIZONTAL
# 4  ANADARKO E&P ONSHORE LLC        Active    HORIZONTAL
#
# [5 rows x 21 columns]

# %%
# get the correct form of APT
welldata02_df['API'] = welldata02_df['API'].str.replace('-','').str.replace('0000','')
welldata02_df['API'] = pd.to_numeric(welldata02_df['API'])

# %%
part2_df.head()
# Out:
#                  API                         Name Well Type - Aliased  \
# 0  42-301-32426-0000  THRESHER 55-1-12 UNIT A 15H              PERMIT
# 1  42-301-32426-0000  THRESHER 55-1-12 UNIT A 15H              PERMIT
# 2  42-301-32427-0000  THRESHER 55-1-12 UNIT A 16H                 OIL
# 3  42-301-32427-0000  THRESHER 55-1-12 UNIT A 16H                 OIL
# 4  42-301-32937-0000  UNIVERSITY 20 PW UNIT 2003H                 OIL
#
#   Status - Aliased Wellbore Profile - Aliased First Production Date   CUM Oil  \
# 0     OPEN SHUT IN                 HORIZONTAL              4/1/2018    9091.0
# 1     OPEN SHUT IN                 HORIZONTAL              4/1/2018    9091.0
# 2           Active                 HORIZONTAL              4/1/2018    9091.0
# 3           Active                 HORIZONTAL              4/1/2018    9091.0
# 4           Active                 HORIZONTAL              4/1/2018  833113.0
#
#     CUM Gas  CUM Water   Latitude   Longitude  Lateral Length   Spud Date  \
# 0   13875.0        0.0  31.981396 -103.710175     9087.059570   1/31/2018
# 1   13875.0        0.0  31.981396 -103.710175     9087.059570   1/31/2018
# 2   13875.0        0.0  31.981394 -103.710083     9079.295898   2/11/2018
# 3   13875.0        0.0  31.981394 -103.710083     9079.295898   2/11/2018
# 4  988451.0        0.0  31.686888 -103.335297     8038.000000  12/18/2017
#
#   Completion Date Well Number  Upper Perf  Lower Perf Formation  \
# 0             NaN         NaN           0           0       NaN
# 1       3/18/2018         15H           0           0       NaN
# 2             NaN         NaN           0           0       NaN
# 3        3/5/2018         16H           0           0       NaN
# 4       9/18/2016       2003H           0           0  WOLFCAMP
#
#                   operator        CUM BOE
# 0                       NaN   11403.50012
# 1  ANADARKO E&P ONSHORE LLC   11403.50012
# 2                       NaN   11403.50012
# 3  ANADARKO E&P ONSHORE LLC   11403.50012
# 4         SHELL WESTERN E&P  997854.83980

# %%
list(part2_df)
# Out:
# ['API',
#  'Name',
#  'Well Type - Aliased',
#  'Status - Aliased',
#  'Wellbore Profile - Aliased',
#  'First Production Date',
#  'CUM Oil',
#  'CUM Gas',
#  'CUM Water',
#  'Latitude',
#  'Longitude',
#  'Lateral Length',
#  'Spud Date',
#  'Completion Date',
#  'Well Number',
#  'Upper Perf',
#  'Lower Perf',
#  'Formation',
#  'operator ',
#  'CUM BOE']

# %%
welldata02_df.rename(columns={             
 
 'Name': 'Lease_Name',
 'Well Type - Aliased': 'Production_Type',
 'Status - Aliased': 'Production_Status',
 'Wellbore Profile - Aliased':'Drilling_Type' ,
 'First Production Date':'First_Production_Day',
 'CUM Oil':'Cum_Oil',
 'CUM Gas':'Cum_Gas',
 'CUM Water':'Cum_water',
 'Latitude':'Lat',
 'Longitude':'Long',
 'Spud Date':'Spud_Date',
 'Completion Date':'Completion_Date',
 'Well Number':'Well_Number',
 'Upper Perf':'Upper_Perforation',
 'Lower Perf':'Lower_Perforation',
 'Formation':'Reservoir',
 'operator':'Operator',
 'CUM BOE':'Cum_BOE'}
                     
                     
                     , inplace=True)

# %%
# welldata02_df
# welldata02_df.dropna(axis = 1)
welldata02_df.head()
# Out:
#           API                     Lease_Name Production_Type  \
# 0  4230132426    THRESHER 55-1-12 UNIT A 15H          PERMIT
# 1  4230132426    THRESHER 55-1-12 UNIT A 15H          PERMIT
# 2  4230132427    THRESHER 55-1-12 UNIT A 16H             OIL
# 3  4230132427    THRESHER 55-1-12 UNIT A 16H             OIL
# 4  4230132973  WAR ADMIRAL 28-4 UNIT D 1H 1H             OIL
#
#   Production_Status Drilling_Type First_Production_Day   Cum_Oil   Cum_Gas  \
# 0      OPEN SHUT IN    HORIZONTAL             4/1/2018    9091.0   13875.0
# 1      OPEN SHUT IN    HORIZONTAL             4/1/2018    9091.0   13875.0
# 2            Active    HORIZONTAL             4/1/2018    9091.0   13875.0
# 3            Active    HORIZONTAL             4/1/2018    9091.0   13875.0
# 4            Active    HORIZONTAL             9/1/2018  228666.0  318442.0
#
#    Cum_water        Lat      ...       Lateral Length  Spud_Date  \
# 0        0.0  31.981396      ...          9087.059570  1/31/2018
# 1        0.0  31.981396      ...          9087.059570  1/31/2018
# 2        0.0  31.981394      ...          9079.295898  2/11/2018
# 3        0.0  31.981394      ...          9079.295898  2/11/2018
# 4        0.0  31.844194      ...         11127.969730  7/12/2018
#
#   Completion_Date Well_Number Upper_Perforation  Lower_Perforation  Reservoir  \
# 0             NaN         NaN                 0                  0        NaN
# 1       3/18/2018         15H                 0                  0        NaN
# 2             NaN         NaN                 0                  0        NaN
# 3        3/5/2018         16H                 0                  0        NaN
# 4       9/21/2018          1H             12689              22769   WOLFCAMP
#
#                   operator         STATUS well profile
# 0                       NaN  OPEN SHUT IN    HORIZONTAL
# 1  ANADARKO E&P ONSHORE LLC  OPEN SHUT IN    HORIZONTAL
# 2                       NaN        Active    HORIZONTAL
# 3  ANADARKO E&P ONSHORE LLC        Active    HORIZONTAL
# 4  ANADARKO E&P ONSHORE LLC        Active    HORIZONTAL
#
# [5 rows x 21 columns]

# %%
frames = [welldata01_df,welldata02_df]
welldata_df = pd.concat(frames)

# welldata_df
# Out:
# C:\Users\hocin\Anaconda\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.

# %%
welldata_df.head()
# Out:
#           API Block Completion_Date  Cum_BOE  Cum_Gas  Cum_Oil  Cum_water  \
# 0  4230133173   NaN             NaN   9292.0  22456.0   5549.0        NaN
# 1  4230133308   NaN             NaN    559.0     72.0    547.0        NaN
# 2  4230133208   NaN             NaN  33618.0  74305.0  21234.0        NaN
# 3  4230133057   NaN             NaN  26351.0  40193.0  19652.0        NaN
# 4  4230133056   NaN             NaN  23117.0  43538.0  15861.0        NaN
#
#    Daily_Gas  Daily_Oil Drilling_Type      ...      STATUS  Section  \
# 0      724.0      179.0             H      ...         NaN      NaN
# 1        2.0       18.0             H      ...         NaN      NaN
# 2     2397.0      685.0             H      ...         NaN      NaN
# 3      659.0      322.0             H      ...         NaN      NaN
# 4     1404.0      512.0             H      ...         NaN      NaN
#
#    Spud_Date       TD  TVD  Upper_Perforation Well_Count  Well_Number  \
# 0  3/27/2017  12100.0  NaN                NaN        1.0           1H
# 1   5/8/2017  20470.0  NaN                NaN        1.0       W102AP
# 2   4/8/2017  14000.0  NaN                NaN        1.0           2H
# 3  1/22/2017  17570.0  NaN                NaN        1.0         101H
# 4  4/24/2017  14375.0  NaN                NaN        1.0       H301DM
#
#    operator  well profile
# 0        NaN           NaN
# 1        NaN           NaN
# 2        NaN           NaN
# 3        NaN           NaN
# 4        NaN           NaN
#
# [5 rows x 43 columns]

# %%
welldata_df.to_csv('data/loving_WellData.csv')
