# %%
import pandas as pd

# %%
data = pd.read_csv(".csv")

# %%
data.head()
# Out:
#         API/UWI              Operator Alias       Well/Lease Name Well Number  \
# 0  4.230130e+13   ANADARKO E&P ONSHORE, LLC   SAVAGE 54-2-22 UNIT          1H
# 1  4.230130e+13      MEWBOURNE HOLDINGS INC     ZUMA 3 57-T1-3X10      W102AP
# 2  4.230130e+13  EOG RESOURCES INCORPORATED  LINK VJ RANCH 23-11B          2H
# 3  4.230130e+13    DEVON ENERGY CORPORATION          BOYD 11 101H        101H
# 4  4.230130e+13      MEWBOURNE HOLDINGS INC                TXL 19      H301DM
#
#   Entity Type County/Parish    Reservoir Production Type Producing Status  \
# 0        WELL   LOVING (TX)     WOLFCAMP             OIL           ACTIVE
# 1        WELL   LOVING (TX)     WOLFCAMP             OIL           ACTIVE
# 2        WELL   LOVING (TX)     WOLFCAMP             OIL           ACTIVE
# 3        WELL   LOVING (TX)     WOLFCAMP             OIL           ACTIVE
# 4        WELL   LOVING (TX)  BONE SPRING             OIL           ACTIVE
#
# ...
