# %%
import pandas as pd

# %%
#read the csv file for well data part1
welldata01_df = pd.read_csv("data/part1_1982-2017.csv")
welldata01_df.head()
# Out:
#           API/UWI              Operator Alias       Well/Lease Name  \
# 0  42301331730000   ANADARKO E&P ONSHORE, LLC   SAVAGE 54-2-22 UNIT
# 1  42301333080000      MEWBOURNE HOLDINGS INC     ZUMA 3 57-T1-3X10
# 2  42301332080000  EOG RESOURCES INCORPORATED  LINK VJ RANCH 23-11B
# 3  42301330570000    DEVON ENERGY CORPORATION          BOYD 11 101H
# 4  42301330560000      MEWBOURNE HOLDINGS INC                TXL 19
#
#   Well Number    Reservoir Production Type Producing Status Drill Type  \
# 0          1H     WOLFCAMP             OIL           ACTIVE          H
# 1      W102AP     WOLFCAMP             OIL           ACTIVE          H
# 2          2H     WOLFCAMP             OIL           ACTIVE          H
# 3        101H     WOLFCAMP             OIL           ACTIVE          H
# 4      H301DM  BONE SPRING             OIL           ACTIVE          H
#
#   First Prod Date Last Prod Date  Cum Gas  Cum Oil  Cum BOE  Daily Gas  \
# ...

# %%
#list all the header column 
list(welldata01_df)
# Out:
# ['API/UWI',
#  'Operator Alias',
#  'Well/Lease Name',
#  'Well Number',
#  'Reservoir',
#  'Production Type',
#  'Producing Status',
#  'Drill Type',
#  'First Prod Date',
#  'Last Prod Date',
#  'Cum Gas',
#  'Cum Oil',
#  'Cum BOE',
#  'Daily Gas',
#  'Daily Oil',
#  'First Month Oil',
#  'First Month Gas',
#  'First 6 Oil',
#  'First 6 Gas',
#  'First 6 BOE',
#  'First 12 Oil',
#  'First 12 Gas',
#  'First 12 BOE',
#  'Last Test Date',
#  'Last Flow Pressure',
#  'Peak Gas',
#  'Peak Oil',
#  'Peak BOE',
#  'Upper Perforation',
#  'Lower Perforation',
#  'Gas Gravity',
#  'Oil Gravity',
#  'Completion Date',
#  'Well Count',
#  'Max Active Wells',
#  'Months Produced',
#  'Lease Number',
#  'Spud Date',
#  'Measured Depth (TD)',
#  'True Vertical Depth',
#  'Perforated Interval Length',
#  'Field',
#  'Section',
#  'Block',
#  'Surface Latitude (WGS84)',
#  'Surface Longitude (WGS84)']

# %%
# renamer the columns header
welldata01_df.rename(columns={
 'API/UWI':'API',
 'Operator Alias': 'Operator',
 'Well/Lease Name':'Lease_Name',
 'Well Number':'Well_Number',
 'Production Type': 'Production_type',
 'Producing Status':'Production_Status',
 'Drill Type':'Drilling_Type',
 'First Prod Date':'First_Peoduction_Day',
 'Last Prod Date': 'Last_Production_Date',
 'Cum Gas':'Cum_Gas',
 'Cum Oil':'Cum_Oil',
 'Cum BOE':'Cum_BOE',
 'Daily Gas':'Daily_Gas',
 'Daily Oil':'Daily_Oil',
 'First Month Oil':'First_Month_Oil',
 'First Month Gas':'First_Month_Gas',
 'First 6 Oil':'First_6_Oil',
 'First 6 Gas':'First_6_Gas',
 'First 6 BOE':'First_6_BOE,
 'First 12 Oil':'First_12_Oil',
 'First 12 Gas':'First 12 Gas',
 'First 12 BOE':'First 12 BOE',
 'Last Test Date':'Last Test Date',
 'Last Flow Pressure':'Last Test Date',
 'Peak Gas',
 'Peak Oil',
 'Peak BOE',
 'Upper Perforation',
 'Lower Perforation',
 'Gas Gravity',
 'Oil Gravity',
 'Completion Date',
 'Well Count',
 'Max Active Wells',
 'Months Produced',
 'Lease Number',
 'Spud Date',
 'Measured Depth (TD)',
 'True Vertical Depth',
 'Perforated Interval Length',
 'Field',
 'Section',
 'Block',
 'Surface Latitude (WGS84)',
 'Surface Longitude (WGS84)']}, inplace=True)

# %%
welldata01_df.head()
# Out:
#               API                    Operator            Lease_Name  \
# 0  42301331730000   ANADARKO E&P ONSHORE, LLC   SAVAGE 54-2-22 UNIT
# 1  42301333080000      MEWBOURNE HOLDINGS INC     ZUMA 3 57-T1-3X10
# 2  42301332080000  EOG RESOURCES INCORPORATED  LINK VJ RANCH 23-11B
# 3  42301330570000    DEVON ENERGY CORPORATION          BOYD 11 101H
# 4  42301330560000      MEWBOURNE HOLDINGS INC                TXL 19
#
#   Well_Number    Reservoir Production_type Production_Status Drilling_Type  \
# 0          1H     WOLFCAMP             OIL            ACTIVE             H
# 1      W102AP     WOLFCAMP             OIL            ACTIVE             H
# 2          2H     WOLFCAMP             OIL            ACTIVE             H
# 3        101H     WOLFCAMP             OIL            ACTIVE             H
# 4      H301DM  BONE SPRING             OIL            ACTIVE             H
#
#   First_Peoduction_Day Last_Production_Date  Cum_Gas  Cum Oil  Cum BOE  \
# ...
